# %%
import pandas as pd
import csv
import matplotlib.pyplot as plt
from sklearn.model_selection import KFold
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score,confusion_matrix,classification_report
from sklearn import preprocessing
from sklearn.preprocessing import Normalizer, MinMaxScaler
from sklearn import neighbors
from sklearn.model_selection import train_test_split
import numpy as np

# %%
def scores(y_test,prediction):
#     print("Accuracy: " + str(accuracy_score(y_test, prediction) * 100) + "%")
#     print("Precision: " + str(precision_score(y_test, prediction) * 100) + "%")
#     print("F1 score: " + str(f1_score(y_test, prediction) * 100) + "%")
#     print("Recall: " + str(recall_score(y_test, prediction) * 100) + "%")
    scores = []
    scores.append(accuracy_score(y_test, prediction) * 100)
    scores.append(precision_score(y_test, prediction) * 100)
    scores.append(f1_score(y_test, prediction) * 100)
    scores.append(recall_score(y_test, prediction) * 100) 
    print('Accuracy:',accuracy_score(y_test, prediction) * 100,'%')
    print(confusion_matrix(y_test,prediction))
    print(classification_report(y_test, prediction, target_names=["red wine","white wine"]))
    return scores

# %%
#carregando dataset de vinhos brancos e vermelhos
wines = pd.read_csv('wines.csv',sep=",")
#separando dados e saidas
X = wines.iloc[:,0:12]
Y = wines.iloc[:,-1]
X_train, X_test, y_train, y_test = train_test_split( X, Y, test_size=0.20, random_state=42)

# %%
clf = neighbors.KNeighborsClassifier(3, weights = 'uniform')
model = clf.fit(X_train, y_train)

# %%
prediction = clf.predict(X_test)
scores(y_test,prediction)
# Out:
# Accuracy: 93.84615384615384 %
# [[291  42]
#  [ 38 929]]
#               precision    recall  f1-score   support
#
#     red wine       0.88      0.87      0.88       333
#   white wine       0.96      0.96      0.96       967
#
#    micro avg       0.94      0.94      0.94      1300
#    macro avg       0.92      0.92      0.92      1300
# weighted avg       0.94      0.94      0.94      1300
# [93.84615384615384, 95.6745623069001, 95.87203302373581, 96.07032057911064]

# %% [markdown]
# <h2>Função Kfold</h2>

# %%
def cross_validation(dados,folds=10):
    scor = []
    kf = KFold(n_splits=folds)
    for train_index, test_index in kf.split(dados):
        X_train, X_test = dados.iloc[train_index], dados.iloc[test_index]
        y_train, y_test = Y[train_index], Y[test_index]
        model = clf.fit(X_train,y_train)
        prediction = model.predict(X_test)
        scor.append(scores(y_test,prediction))
    return scor

# %%
normalizer = Normalizer(norm='l1')
winesl1 = X.copy()
winesl1.iloc[0:,0:12] = normalizer.transform(X)
winesl1.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0       0.030496          0.000659     0.001236        0.056459   0.000231
# 1       0.037031          0.002051     0.001766        0.077195   0.000302
# 2       0.086411          0.003227     0.004060        0.024986   0.000812
# 3       0.036697          0.003556     0.002356        0.009061   0.000553
# 4       0.042753          0.001579     0.002499        0.006577   0.000178
#
#    free sulfur dioxide  total sulfur dioxide   density        pH  sulphates  \
# 0             0.135996              0.692343  0.004114  0.011951   0.001813
# 1             0.113942              0.643770  0.005671  0.018231   0.003190
# 2             0.176987              0.447672  0.010353  0.034460   0.008016
# 3             0.167630              0.693174  0.004517  0.014543   0.003126
# 4             0.203899              0.591964  0.006507  0.021311   0.002368
#
#     alcohol   quality
# 0  0.035853  0.028848
# 1  0.062668  0.034182
# 2  0.130137  0.072877
# 3  0.042134  0.022653
# 4  0.080902  0.039464

# %%
scorl1 = cross_validation(winesl1)
# Out:
# Accuracy: 95.6923076923077 %
# [[140  20]
#  [  8 482]]
#               precision    recall  f1-score   support
#
#     red wine       0.95      0.88      0.91       160
#   white wine       0.96      0.98      0.97       490
#
#    micro avg       0.96      0.96      0.96       650
#    macro avg       0.95      0.93      0.94       650
# weighted avg       0.96      0.96      0.96       650
#
# Accuracy: 96.0 %
# [[140  14]
#  [ 12 484]]
#               precision    recall  f1-score   support
#
#     red wine       0.92      0.91      0.92       154
#   white wine       0.97      0.98      0.97       496
#
#    micro avg       0.96      0.96      0.96       650
#    macro avg       0.95      0.94      0.94       650
# weighted avg       0.96      0.96      0.96       650
#
# Accuracy: 96.0 %
# [[154  15]
#  [ 11 470]]
#               precision    recall  f1-score   support
#
#     red wine       0.93      0.91      0.92       169
#   white wine       0.97      0.98      0.97       481
#
#    micro avg       0.96      0.96      0.96       650
#    macro avg       0.95      0.94      0.95       650
# weighted avg       0.96      0.96      0.96       650
#
# Accuracy: 96.0 %
# [[158  16]
#  [ 10 466]]
#               precision    recall  f1-score   support
#
#     red wine       0.94      0.91      0.92       174
#   white wine       0.97      0.98      0.97       476
#
#    micro avg       0.96      0.96      0.96       650
#    macro avg       0.95      0.94      0.95       650
# weighted avg       0.96      0.96      0.96       650
#
# Accuracy: 94.61538461538461 %
# [[137  20]
#  [ 15 478]]
#               precision    recall  f1-score   support
#
#     red wine       0.90      0.87      0.89       157
#   white wine       0.96      0.97      0.96       493
#
#    micro avg       0.95      0.95      0.95       650
#    macro avg       0.93      0.92      0.93       650
# weighted avg       0.95      0.95      0.95       650
#
# Accuracy: 95.6923076923077 %
# [[142  15]
#  [ 13 480]]
#               precision    recall  f1-score   support
#
#     red wine       0.92      0.90      0.91       157
#   white wine       0.97      0.97      0.97       493
#
#    micro avg       0.96      0.96      0.96       650
#    macro avg       0.94      0.94      0.94       650
# weighted avg       0.96      0.96      0.96       650
#
# Accuracy: 96.3076923076923 %
# [[143  16]
#  [  8 483]]
#               precision    recall  f1-score   support
#
#     red wine       0.95      0.90      0.92       159
#   white wine       0.97      0.98      0.98       491
#
#    micro avg       0.96      0.96      0.96       650
#    macro avg       0.96      0.94      0.95       650
# weighted avg       0.96      0.96      0.96       650
#
# Accuracy: 95.22342064714945 %
# [[145  18]
#  [ 13 473]]
#               precision    recall  f1-score   support
#
#     red wine       0.92      0.89      0.90       163
#   white wine       0.96      0.97      0.97       486
#
#    micro avg       0.95      0.95      0.95       649
#    macro avg       0.94      0.93      0.94       649
# weighted avg       0.95      0.95      0.95       649
#
# Accuracy: 96.61016949152543 %
# [[139  10]
#  [ 12 488]]
#               precision    recall  f1-score   support
#
#     red wine       0.92      0.93      0.93       149
#   white wine       0.98      0.98      0.98       500
#
#    micro avg       0.97      0.97      0.97       649
#    macro avg       0.95      0.95      0.95       649
# weighted avg       0.97      0.97      0.97       649
#
# Accuracy: 95.99383667180277 %
# [[143  14]
#  [ 12 480]]
#               precision    recall  f1-score   support
#
#     red wine       0.92      0.91      0.92       157
#   white wine       0.97      0.98      0.97       492
#
#    micro avg       0.96      0.96      0.96       649
#    macro avg       0.95      0.94      0.95       649
# weighted avg       0.96      0.96      0.96       649

# %%
normalizer = Normalizer(norm='l2')
winesl2 = X.copy()
winesl2.iloc[0:,0:12] = normalizer.transform(X)
winesl2.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0       0.042946          0.000929     0.001741        0.079509   0.000325
# 1       0.055812          0.003091     0.002662        0.116346   0.000455
# 2       0.168350          0.006288     0.007910        0.048680   0.001582
# 3       0.051258          0.004968     0.003291        0.012656   0.000772
# 4       0.067390          0.002488     0.003940        0.010368   0.000280
#
#    free sulfur dioxide  total sulfur dioxide   density        pH  sulphates  \
# 0             0.191518              0.975001  0.005793  0.016830   0.002554
# 1             0.171728              0.970265  0.008547  0.027477   0.004808
# 2             0.344813              0.872175  0.020170  0.067137   0.015618
# 3             0.234141              0.968204  0.006309  0.020313   0.004366
# 4             0.321397              0.933089  0.010256  0.033591   0.003732
#
#     alcohol   quality
# 0  0.050491  0.040625
# 1  0.094451  0.051519
# 2  0.253539  0.141982
# 3  0.058852  0.031641
# 4  0.127522  0.062206

# %%
scorl2 = cross_validation(winesl2)
# Out:
# Accuracy: 94.61538461538461 %
# [[137  23]
#  [ 12 478]]
#               precision    recall  f1-score   support
#
#     red wine       0.92      0.86      0.89       160
#   white wine       0.95      0.98      0.96       490
#
#    micro avg       0.95      0.95      0.95       650
#    macro avg       0.94      0.92      0.93       650
# weighted avg       0.95      0.95      0.95       650
#
# Accuracy: 96.76923076923077 %
# [[141  13]
#  [  8 488]]
#               precision    recall  f1-score   support
#
#     red wine       0.95      0.92      0.93       154
#   white wine       0.97      0.98      0.98       496
#
#    micro avg       0.97      0.97      0.97       650
#    macro avg       0.96      0.95      0.95       650
# weighted avg       0.97      0.97      0.97       650
#
# Accuracy: 95.6923076923077 %
# [[152  17]
#  [ 11 470]]
#               precision    recall  f1-score   support
#
#     red wine       0.93      0.90      0.92       169
#   white wine       0.97      0.98      0.97       481
#
#    micro avg       0.96      0.96      0.96       650
#    macro avg       0.95      0.94      0.94       650
# weighted avg       0.96      0.96      0.96       650
#
# Accuracy: 96.0 %
# [[157  17]
#  [  9 467]]
#               precision    recall  f1-score   support
#
#     red wine       0.95      0.90      0.92       174
#   white wine       0.96      0.98      0.97       476
#
#    micro avg       0.96      0.96      0.96       650
#    macro avg       0.96      0.94      0.95       650
# weighted avg       0.96      0.96      0.96       650
#
# Accuracy: 94.46153846153847 %
# [[136  21]
#  [ 15 478]]
#               precision    recall  f1-score   support
#
#     red wine       0.90      0.87      0.88       157
#   white wine       0.96      0.97      0.96       493
#
#    micro avg       0.94      0.94      0.94       650
#    macro avg       0.93      0.92      0.92       650
# weighted avg       0.94      0.94      0.94       650
#
# Accuracy: 94.92307692307692 %
# [[139  18]
#  [ 15 478]]
#               precision    recall  f1-score   support
#
#     red wine       0.90      0.89      0.89       157
#   white wine       0.96      0.97      0.97       493
#
#    micro avg       0.95      0.95      0.95       650
#    macro avg       0.93      0.93      0.93       650
# weighted avg       0.95      0.95      0.95       650
#
# Accuracy: 95.38461538461539 %
# [[141  18]
#  [ 12 479]]
#               precision    recall  f1-score   support
#
#     red wine       0.92      0.89      0.90       159
#   white wine       0.96      0.98      0.97       491
#
#    micro avg       0.95      0.95      0.95       650
#    macro avg       0.94      0.93      0.94       650
# weighted avg       0.95      0.95      0.95       650
#
# Accuracy: 95.83975346687211 %
# [[145  18]
#  [  9 477]]
#               precision    recall  f1-score   support
#
#     red wine       0.94      0.89      0.91       163
#   white wine       0.96      0.98      0.97       486
#
#    micro avg       0.96      0.96      0.96       649
#    macro avg       0.95      0.94      0.94       649
# weighted avg       0.96      0.96      0.96       649
#
# Accuracy: 96.61016949152543 %
# [[140   9]
#  [ 13 487]]
#               precision    recall  f1-score   support
#
#     red wine       0.92      0.94      0.93       149
#   white wine       0.98      0.97      0.98       500
#
#    micro avg       0.97      0.97      0.97       649
#    macro avg       0.95      0.96      0.95       649
# weighted avg       0.97      0.97      0.97       649
#
# Accuracy: 96.61016949152543 %
# [[143  14]
#  [  8 484]]
#               precision    recall  f1-score   support
#
#     red wine       0.95      0.91      0.93       157
#   white wine       0.97      0.98      0.98       492
#
#    micro avg       0.97      0.97      0.97       649
#    macro avg       0.96      0.95      0.95       649
# weighted avg       0.97      0.97      0.97       649

# %%
normalizer = Normalizer(norm='max')
winesmax = X.copy()
winesmax.iloc[0:,0:12] = normalizer.transform(X)
winesmax.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0       0.044048          0.000952     0.001786        0.081548   0.000333
# 1       0.057522          0.003186     0.002743        0.119912   0.000469
# 2       0.193023          0.007209     0.009070        0.055814   0.001814
# 3       0.052941          0.005131     0.003399        0.013072   0.000797
# 4       0.072222          0.002667     0.004222        0.011111   0.000300
#
#    free sulfur dioxide  total sulfur dioxide   density        pH  sulphates  \
# 0             0.196429                   1.0  0.005942  0.017262   0.002619
# 1             0.176991                   1.0  0.008809  0.028319   0.004956
# 2             0.395349                   1.0  0.023127  0.076977   0.017907
# 3             0.241830                   1.0  0.006516  0.020980   0.004510
# 4             0.344444                   1.0  0.010992  0.036000   0.004000
#
#     alcohol   quality
# 0  0.051786  0.041667
# 1  0.097345  0.053097
# 2  0.290698  0.162791
# 3  0.060784  0.032680
# 4  0.136667  0.066667

# %%
scormax = cross_validation(winesmax)
# Out:
# Accuracy: 94.61538461538461 %
# [[137  23]
#  [ 12 478]]
#               precision    recall  f1-score   support
#
#     red wine       0.92      0.86      0.89       160
#   white wine       0.95      0.98      0.96       490
#
#    micro avg       0.95      0.95      0.95       650
#    macro avg       0.94      0.92      0.93       650
# weighted avg       0.95      0.95      0.95       650
#
# Accuracy: 96.76923076923077 %
# [[141  13]
#  [  8 488]]
#               precision    recall  f1-score   support
#
#     red wine       0.95      0.92      0.93       154
#   white wine       0.97      0.98      0.98       496
#
#    micro avg       0.97      0.97      0.97       650
#    macro avg       0.96      0.95      0.95       650
# weighted avg       0.97      0.97      0.97       650
#
# Accuracy: 95.53846153846153 %
# [[152  17]
#  [ 12 469]]
#               precision    recall  f1-score   support
#
#     red wine       0.93      0.90      0.91       169
#   white wine       0.97      0.98      0.97       481
#
#    micro avg       0.96      0.96      0.96       650
#    macro avg       0.95      0.94      0.94       650
# weighted avg       0.96      0.96      0.96       650
#
# Accuracy: 96.0 %
# [[157  17]
#  [  9 467]]
#               precision    recall  f1-score   support
#
#     red wine       0.95      0.90      0.92       174
#   white wine       0.96      0.98      0.97       476
#
#    micro avg       0.96      0.96      0.96       650
#    macro avg       0.96      0.94      0.95       650
# weighted avg       0.96      0.96      0.96       650
#
# Accuracy: 94.46153846153847 %
# [[136  21]
#  [ 15 478]]
#               precision    recall  f1-score   support
#
#     red wine       0.90      0.87      0.88       157
#   white wine       0.96      0.97      0.96       493
#
#    micro avg       0.94      0.94      0.94       650
#    macro avg       0.93      0.92      0.92       650
# weighted avg       0.94      0.94      0.94       650
#
# Accuracy: 95.07692307692308 %
# [[140  17]
#  [ 15 478]]
#               precision    recall  f1-score   support
#
#     red wine       0.90      0.89      0.90       157
#   white wine       0.97      0.97      0.97       493
#
#    micro avg       0.95      0.95      0.95       650
#    macro avg       0.93      0.93      0.93       650
# weighted avg       0.95      0.95      0.95       650
#
# Accuracy: 95.38461538461539 %
# [[141  18]
#  [ 12 479]]
#               precision    recall  f1-score   support
#
#     red wine       0.92      0.89      0.90       159
#   white wine       0.96      0.98      0.97       491
#
#    micro avg       0.95      0.95      0.95       650
#    macro avg       0.94      0.93      0.94       650
# weighted avg       0.95      0.95      0.95       650
#
# Accuracy: 95.83975346687211 %
# [[145  18]
#  [  9 477]]
#               precision    recall  f1-score   support
#
#     red wine       0.94      0.89      0.91       163
#   white wine       0.96      0.98      0.97       486
#
#    micro avg       0.96      0.96      0.96       649
#    macro avg       0.95      0.94      0.94       649
# weighted avg       0.96      0.96      0.96       649
#
# Accuracy: 96.61016949152543 %
# [[140   9]
#  [ 13 487]]
#               precision    recall  f1-score   support
#
#     red wine       0.92      0.94      0.93       149
#   white wine       0.98      0.97      0.98       500
#
#    micro avg       0.97      0.97      0.97       649
#    macro avg       0.95      0.96      0.95       649
# weighted avg       0.97      0.97      0.97       649
#
# Accuracy: 96.61016949152543 %
# [[142  15]
#  [  7 485]]
#               precision    recall  f1-score   support
#
#     red wine       0.95      0.90      0.93       157
#   white wine       0.97      0.99      0.98       492
#
#    micro avg       0.97      0.97      0.97       649
#    macro avg       0.96      0.95      0.95       649
# weighted avg       0.97      0.97      0.97       649

# %%
scaller = MinMaxScaler(feature_range=(0, 12))
winesminmax = X.copy()
winesminmax.iloc[0:,0:12] = scaller.fit_transform(X)
winesminmax.head()
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/preprocessing/data.py:323: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by MinMaxScaler.
#   return self.partial_fit(X, y)
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0       3.570248              0.64     2.168675        2.411043   0.936877
# 1       2.677686              2.24     2.240964        2.383436   0.877076
# 2       4.462810              1.84     2.819277        0.331288   1.375415
# 3       4.264463              5.64     3.759036        0.257669   2.252492
# 4       2.677686              1.28     2.746988        0.073620   0.358804
#
#    free sulfur dioxide  total sulfur dioxide   density        pH  sulphates  \
# 0             1.333333              4.479263  2.577212  1.674419   1.483146
# 1             0.791667              2.958525  1.927126  4.465116   2.292135
# 2             0.666667              1.023041  1.695778  5.488372   3.707865
# 3             1.500000              4.064516  2.264893  4.558140   3.168539
# 4             1.250000              2.322581  0.497397  4.837209   0.943820
#
#     alcohol  quality
# 0  1.217391      8.0
# 1  5.217391      6.0
# 2  7.826087      8.0
# 3  2.260870      4.0
# 4  7.478261      6.0

# %%
scorminmax = cross_validation(winesminmax)
# Out:
# Accuracy: 99.23076923076923 %
# [[156   4]
#  [  1 489]]
#               precision    recall  f1-score   support
#
#     red wine       0.99      0.97      0.98       160
#   white wine       0.99      1.00      0.99       490
#
#    micro avg       0.99      0.99      0.99       650
#    macro avg       0.99      0.99      0.99       650
# weighted avg       0.99      0.99      0.99       650
#
# Accuracy: 99.07692307692308 %
# [[153   1]
#  [  5 491]]
#               precision    recall  f1-score   support
#
#     red wine       0.97      0.99      0.98       154
#   white wine       1.00      0.99      0.99       496
#
#    micro avg       0.99      0.99      0.99       650
#    macro avg       0.98      0.99      0.99       650
# weighted avg       0.99      0.99      0.99       650
#
# Accuracy: 99.23076923076923 %
# [[166   3]
#  [  2 479]]
#               precision    recall  f1-score   support
#
#     red wine       0.99      0.98      0.99       169
#   white wine       0.99      1.00      0.99       481
#
#    micro avg       0.99      0.99      0.99       650
#    macro avg       0.99      0.99      0.99       650
# weighted avg       0.99      0.99      0.99       650
#
# Accuracy: 98.76923076923076 %
# [[170   4]
#  [  4 472]]
#               precision    recall  f1-score   support
#
#     red wine       0.98      0.98      0.98       174
#   white wine       0.99      0.99      0.99       476
#
#    micro avg       0.99      0.99      0.99       650
#    macro avg       0.98      0.98      0.98       650
# weighted avg       0.99      0.99      0.99       650
#
# Accuracy: 98.76923076923076 %
# [[151   6]
#  [  2 491]]
#               precision    recall  f1-score   support
#
#     red wine       0.99      0.96      0.97       157
#   white wine       0.99      1.00      0.99       493
#
#    micro avg       0.99      0.99      0.99       650
#    macro avg       0.99      0.98      0.98       650
# weighted avg       0.99      0.99      0.99       650
#
# Accuracy: 99.38461538461539 %
# [[157   0]
#  [  4 489]]
#               precision    recall  f1-score   support
#
#     red wine       0.98      1.00      0.99       157
#   white wine       1.00      0.99      1.00       493
#
#    micro avg       0.99      0.99      0.99       650
#    macro avg       0.99      1.00      0.99       650
# weighted avg       0.99      0.99      0.99       650
#
# Accuracy: 98.76923076923076 %
# [[153   6]
#  [  2 489]]
#               precision    recall  f1-score   support
#
#     red wine       0.99      0.96      0.97       159
#   white wine       0.99      1.00      0.99       491
#
#    micro avg       0.99      0.99      0.99       650
#    macro avg       0.99      0.98      0.98       650
# weighted avg       0.99      0.99      0.99       650
#
# Accuracy: 99.69183359013869 %
# [[161   2]
#  [  0 486]]
#               precision    recall  f1-score   support
#
#     red wine       1.00      0.99      0.99       163
#   white wine       1.00      1.00      1.00       486
#
#    micro avg       1.00      1.00      1.00       649
#    macro avg       1.00      0.99      1.00       649
# weighted avg       1.00      1.00      1.00       649
#
# Accuracy: 99.69183359013869 %
# [[148   1]
#  [  1 499]]
#               precision    recall  f1-score   support
#
#     red wine       0.99      0.99      0.99       149
#   white wine       1.00      1.00      1.00       500
#
#    micro avg       1.00      1.00      1.00       649
#    macro avg       1.00      1.00      1.00       649
# weighted avg       1.00      1.00      1.00       649
#
# Accuracy: 99.53775038520801 %
# [[156   1]
#  [  2 490]]
#               precision    recall  f1-score   support
#
#     red wine       0.99      0.99      0.99       157
#   white wine       1.00      1.00      1.00       492
#
#    micro avg       1.00      1.00      1.00       649
#    macro avg       0.99      0.99      0.99       649
# weighted avg       1.00      1.00      1.00       649

# %%
# Create scaler
scaler = preprocessing.StandardScaler()

# Transform the feature
standardized = scaler.fit_transform(X)

# Show feature
winesS = X.copy()
winesS.iloc[0:,0:12] = standardized
winesS.head()
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/preprocessing/data.py:625: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# /usr/local/lib/python3.6/dist-packages/sklearn/base.py:462: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, **fit_params).transform(X)
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0       0.142473         -1.091373    -0.128234        1.735549  -0.000967
# 1      -0.551792          0.123518    -0.059414        1.704019  -0.086605
# 2       0.836739         -0.180205     0.491146       -0.639680   0.627050
# 3       0.682458          2.705162     1.385805       -0.723758   1.883084
# 4      -0.551792         -0.605417     0.422326       -0.933956  -0.828807
#
#    free sulfur dioxide  total sulfur dioxide   density        pH  sulphates  \
# 0             0.139434              0.924588  1.185071 -1.981037  -0.613385
# 1            -0.593041             -0.048561  0.247917 -0.115073   0.193097
# 2            -0.762074             -1.287116 -0.085589  0.569114   1.604440
# 3             0.364811              0.659184  0.734837 -0.052874   1.066785
# 4             0.026746             -0.455515 -1.813153  0.133722  -1.151040
#
#     alcohol   quality
# 0 -1.502407  1.353228
# 1  0.426120  0.207999
# 2  1.683855  1.353228
# 3 -0.999313 -0.937230
# 4  1.516157  0.207999

# %%
scorss = cross_validation(winesS)
# Out:
# Accuracy: 99.38461538461539 %
# [[157   3]
#  [  1 489]]
#               precision    recall  f1-score   support
#
#     red wine       0.99      0.98      0.99       160
#   white wine       0.99      1.00      1.00       490
#
#    micro avg       0.99      0.99      0.99       650
#    macro avg       0.99      0.99      0.99       650
# weighted avg       0.99      0.99      0.99       650
#
# Accuracy: 99.6923076923077 %
# [[153   1]
#  [  1 495]]
#               precision    recall  f1-score   support
#
#     red wine       0.99      0.99      0.99       154
#   white wine       1.00      1.00      1.00       496
#
#    micro avg       1.00      1.00      1.00       650
#    macro avg       1.00      1.00      1.00       650
# weighted avg       1.00      1.00      1.00       650
#
# Accuracy: 99.53846153846155 %
# [[167   2]
#  [  1 480]]
#               precision    recall  f1-score   support
#
#     red wine       0.99      0.99      0.99       169
#   white wine       1.00      1.00      1.00       481
#
#    micro avg       1.00      1.00      1.00       650
#    macro avg       0.99      0.99      0.99       650
# weighted avg       1.00      1.00      1.00       650
#
# Accuracy: 99.38461538461539 %
# [[171   3]
#  [  1 475]]
#               precision    recall  f1-score   support
#
#     red wine       0.99      0.98      0.99       174
#   white wine       0.99      1.00      1.00       476
#
#    micro avg       0.99      0.99      0.99       650
#    macro avg       0.99      0.99      0.99       650
# weighted avg       0.99      0.99      0.99       650
#
# Accuracy: 99.07692307692308 %
# [[152   5]
#  [  1 492]]
#               precision    recall  f1-score   support
#
#     red wine       0.99      0.97      0.98       157
#   white wine       0.99      1.00      0.99       493
#
#    micro avg       0.99      0.99      0.99       650
#    macro avg       0.99      0.98      0.99       650
# weighted avg       0.99      0.99      0.99       650
#
# Accuracy: 99.38461538461539 %
# [[157   0]
#  [  4 489]]
#               precision    recall  f1-score   support
#
#     red wine       0.98      1.00      0.99       157
#   white wine       1.00      0.99      1.00       493
#
#    micro avg       0.99      0.99      0.99       650
#    macro avg       0.99      1.00      0.99       650
# weighted avg       0.99      0.99      0.99       650
#
# Accuracy: 98.92307692307692 %
# [[154   5]
#  [  2 489]]
#               precision    recall  f1-score   support
#
#     red wine       0.99      0.97      0.98       159
#   white wine       0.99      1.00      0.99       491
#
#    micro avg       0.99      0.99      0.99       650
#    macro avg       0.99      0.98      0.99       650
# weighted avg       0.99      0.99      0.99       650
#
# Accuracy: 99.69183359013869 %
# [[161   2]
#  [  0 486]]
#               precision    recall  f1-score   support
#
#     red wine       1.00      0.99      0.99       163
#   white wine       1.00      1.00      1.00       486
#
#    micro avg       1.00      1.00      1.00       649
#    macro avg       1.00      0.99      1.00       649
# weighted avg       1.00      1.00      1.00       649
#
# Accuracy: 99.38366718027734 %
# [[147   2]
#  [  2 498]]
#               precision    recall  f1-score   support
#
#     red wine       0.99      0.99      0.99       149
#   white wine       1.00      1.00      1.00       500
#
#    micro avg       0.99      0.99      0.99       649
#    macro avg       0.99      0.99      0.99       649
# weighted avg       0.99      0.99      0.99       649
#
# Accuracy: 99.38366718027734 %
# [[155   2]
#  [  2 490]]
#               precision    recall  f1-score   support
#
#     red wine       0.99      0.99      0.99       157
#   white wine       1.00      1.00      1.00       492
#
#    micro avg       0.99      0.99      0.99       649
#    macro avg       0.99      0.99      0.99       649
# weighted avg       0.99      0.99      0.99       649

# %%
def plot_graph(scor, pp):
    measures = ["accuracy","precision","f1-score","recall"]
    data = {s:{'Run '+str(i):scor[i][k] for i in range(10)}for k,s in enumerate(measures)}
    df = pd.DataFrame(data)

    df.plot(kind='barh',figsize=(20,20))

    for i in range(86,101):
        plt.axvline(x=i, color='k', linestyle='--')

    plt.xlim(85,101)
    plt.title('K-Nearest neighbors x '+pp+' x 3 neighbors')
    plt.savefig('images_graphs/'+pp+'knn.png')
    plt.show()
import matplotlib
font = {'family' : 'normal',
        'weight' : 'bold',
        'size'   : 22}

matplotlib.rc('font', **font)

# %%
pps = ['norm l1','norm l2','norm max','minmax scaler','Standard Scaler']
scs = [scorl1,scorl2,scormax,scorminmax,scorss]
for pp,sc in zip(pps,scs):
    plot_graph(sc,pp)
