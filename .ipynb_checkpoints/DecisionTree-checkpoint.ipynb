# %% [markdown]
# <h2>Impotando dependências</h2>

# %%
import pandas as pd
import csv
import matplotlib.pyplot as plt
from sklearn.model_selection import KFold
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score,confusion_matrix,classification_report
from sklearn import preprocessing
from sklearn.preprocessing import Normalizer,MinMaxScaler
from sklearn.tree import DecisionTreeClassifier
from IPython.display import Image  
from sklearn import tree
#import pydotplus
import numpy as np

# %% [markdown]
# <h2>Função de scores</h2>

# %%
def scores(y_test,prediction):
#     print("Accuracy: " + str(accuracy_score(y_test, prediction) * 100) + "%")
#     print("Precision: " + str(precision_score(y_test, prediction) * 100) + "%")
#     print("F1 score: " + str(f1_score(y_test, prediction) * 100) + "%")
#     print("Recall: " + str(recall_score(y_test, prediction) * 100) + "%")
#    scores = []
#    scores.append(accuracy_score(y_test, prediction) * 100)
#    scores.append(precision_score(y_test, prediction) * 100)
#    scores.append(f1_score(y_test, prediction) * 100)
#    scores.append(recall_score(y_test, prediction) * 100) 
    print('Accuracy:',accuracy_score(y_test, prediction) * 100,'%')
    print(confusion_matrix(y_test,prediction))
    print(classification_report(y_test, prediction, target_names=["red wine","white wine"]))

# %% [markdown]
# <h3>Função para salvar imagens das árvores de decisão</h3>

# %%
def save_decision_tree(i,dados,classes):
    dot_data = tree.export_graphviz(clf, out_file=None, 
                                feature_names=dados.columns[0:12],  
                                class_names=classes)

    # Draw graph
    graph = pydotplus.graph_from_dot_data(dot_data)  
    graph.write_png("tree_images/wines"+str(i)+".png")

# %% [markdown]
# <h2>Carregando dataset</h2>

# %%
#carregando dataset de vinhos brancos e vermelhos
wines = pd.read_csv('wines.csv',sep=",")
#separando dados e saidas
X = wines.iloc[:,0:12]
Y = wines.iloc[:,-1]

# %% [markdown]
# <h2>Normalizando dados</h2>

# %% [markdown]
# <h3>Pela norma l1</h3>

# %%
normalizer = Normalizer(norm='l1')
winesl1 = X.copy()
winesl1.iloc[0:,0:12] = normalizer.transform(X)
winesl1.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0       0.030496          0.000659     0.001236        0.056459   0.000231
# 1       0.037031          0.002051     0.001766        0.077195   0.000302
# 2       0.086411          0.003227     0.004060        0.024986   0.000812
# 3       0.036697          0.003556     0.002356        0.009061   0.000553
# 4       0.042753          0.001579     0.002499        0.006577   0.000178
#
#    free sulfur dioxide  total sulfur dioxide   density        pH  sulphates  \
# 0             0.135996              0.692343  0.004114  0.011951   0.001813
# 1             0.113942              0.643770  0.005671  0.018231   0.003190
# 2             0.176987              0.447672  0.010353  0.034460   0.008016
# 3             0.167630              0.693174  0.004517  0.014543   0.003126
# 4             0.203899              0.591964  0.006507  0.021311   0.002368
#
#     alcohol   quality
# 0  0.035853  0.028848
# 1  0.062668  0.034182
# 2  0.130137  0.072877
# 3  0.042134  0.022653
# 4  0.080902  0.039464

# %%
# Create decision tree classifer object using gini
clf = DecisionTreeClassifier(criterion='gini', random_state=0)

# %% [markdown]
# <h3>Kfold</h3>

# %%
def cross_validation(dados,folds=10):
    kf = KFold(n_splits=folds)
    for train_index, test_index in kf.split(dados):
        X_train, X_test = dados.iloc[train_index], dados.iloc[test_index]
        y_train, y_test = Y[train_index], Y[test_index]
        model = clf.fit(X_train,y_train)
        prediction = model.predict(X_test)
        classes =[str(x) for x in list(model.classes_)]
        #save_decision_tree(i,dados,classes)
        scores(y_test,prediction)

# %%
cross_validation(winesl1,12)
# Out:
# Accuracy: 97.97047970479706 %
# [[130   5]
#  [  6 401]]
#               precision    recall  f1-score   support
#
#     red wine       0.96      0.96      0.96       135
#   white wine       0.99      0.99      0.99       407
#
#    micro avg       0.98      0.98      0.98       542
#    macro avg       0.97      0.97      0.97       542
# weighted avg       0.98      0.98      0.98       542
#
# Accuracy: 98.5239852398524 %
# [[135   3]
#  [  5 399]]
#               precision    recall  f1-score   support
#
#     red wine       0.96      0.98      0.97       138
#   white wine       0.99      0.99      0.99       404
#
#    micro avg       0.99      0.99      0.99       542
#    macro avg       0.98      0.98      0.98       542
# weighted avg       0.99      0.99      0.99       542
#
# Accuracy: 98.33948339483395 %
# [[118   4]
#  [  5 415]]
#               precision    recall  f1-score   support
#
#     red wine       0.96      0.97      0.96       122
#   white wine       0.99      0.99      0.99       420
#
#    micro avg       0.98      0.98      0.98       542
#    macro avg       0.97      0.98      0.98       542
# weighted avg       0.98      0.98      0.98       542
#
# Accuracy: 98.33948339483395 %
# [[148   4]
#  [  5 385]]
#               precision    recall  f1-score   support
#
#     red wine       0.97      0.97      0.97       152
#   white wine       0.99      0.99      0.99       390
#
#    micro avg       0.98      0.98      0.98       542
#    macro avg       0.98      0.98      0.98       542
# weighted avg       0.98      0.98      0.98       542
#
# Accuracy: 98.5239852398524 %
# [[137   3]
#  [  5 397]]
#               precision    recall  f1-score   support
#
#     red wine       0.96      0.98      0.97       140
#   white wine       0.99      0.99      0.99       402
#
#    micro avg       0.99      0.99      0.99       542
#    macro avg       0.98      0.98      0.98       542
# weighted avg       0.99      0.99      0.99       542
#
# Accuracy: 97.22735674676525 %
# [[117  10]
#  [  5 409]]
#               precision    recall  f1-score   support
#
#     red wine       0.96      0.92      0.94       127
#   white wine       0.98      0.99      0.98       414
#
#    micro avg       0.97      0.97      0.97       541
#    macro avg       0.97      0.95      0.96       541
# weighted avg       0.97      0.97      0.97       541
#
# Accuracy: 97.96672828096118 %
# [[131   5]
#  [  6 399]]
#               precision    recall  f1-score   support
#
#     red wine       0.96      0.96      0.96       136
#   white wine       0.99      0.99      0.99       405
#
#    micro avg       0.98      0.98      0.98       541
#    macro avg       0.97      0.97      0.97       541
# weighted avg       0.98      0.98      0.98       541
#
# Accuracy: 96.67282809611831 %
# [[116  10]
#  [  8 407]]
#               precision    recall  f1-score   support
#
#     red wine       0.94      0.92      0.93       126
#   white wine       0.98      0.98      0.98       415
#
#    micro avg       0.97      0.97      0.97       541
#    macro avg       0.96      0.95      0.95       541
# weighted avg       0.97      0.97      0.97       541
#
# Accuracy: 98.52125693160814 %
# [[132   3]
#  [  5 401]]
#               precision    recall  f1-score   support
#
#     red wine       0.96      0.98      0.97       135
#   white wine       0.99      0.99      0.99       406
#
#    micro avg       0.99      0.99      0.99       541
#    macro avg       0.98      0.98      0.98       541
# weighted avg       0.99      0.99      0.99       541
#
# Accuracy: 99.26062846580407 %
# [[125   3]
#  [  1 412]]
#               precision    recall  f1-score   support
#
#     red wine       0.99      0.98      0.98       128
#   white wine       0.99      1.00      1.00       413
#
#    micro avg       0.99      0.99      0.99       541
#    macro avg       0.99      0.99      0.99       541
# weighted avg       0.99      0.99      0.99       541
#
# Accuracy: 98.15157116451016 %
# [[121   3]
#  [  7 410]]
#               precision    recall  f1-score   support
#
#     red wine       0.95      0.98      0.96       124
#   white wine       0.99      0.98      0.99       417
#
#    micro avg       0.98      0.98      0.98       541
#    macro avg       0.97      0.98      0.97       541
# weighted avg       0.98      0.98      0.98       541
#
# Accuracy: 98.15157116451016 %
# [[132   4]
#  [  6 399]]
#               precision    recall  f1-score   support
#
#     red wine       0.96      0.97      0.96       136
#   white wine       0.99      0.99      0.99       405
#
#    micro avg       0.98      0.98      0.98       541
#    macro avg       0.97      0.98      0.98       541
# weighted avg       0.98      0.98      0.98       541

# %% [markdown]
# <h3>Pela norma l2</h3>

# %%
normalizer = Normalizer(norm='l2')
winesl2 = X.copy()
winesl2.iloc[0:,0:12] = normalizer.transform(X)
winesl2.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0       0.042946          0.000929     0.001741        0.079509   0.000325
# 1       0.055812          0.003091     0.002662        0.116346   0.000455
# 2       0.168350          0.006288     0.007910        0.048680   0.001582
# 3       0.051258          0.004968     0.003291        0.012656   0.000772
# 4       0.067390          0.002488     0.003940        0.010368   0.000280
#
#    free sulfur dioxide  total sulfur dioxide   density        pH  sulphates  \
# 0             0.191518              0.975001  0.005793  0.016830   0.002554
# 1             0.171728              0.970265  0.008547  0.027477   0.004808
# 2             0.344813              0.872175  0.020170  0.067137   0.015618
# 3             0.234141              0.968204  0.006309  0.020313   0.004366
# 4             0.321397              0.933089  0.010256  0.033591   0.003732
#
#     alcohol   quality
# 0  0.050491  0.040625
# 1  0.094451  0.051519
# 2  0.253539  0.141982
# 3  0.058852  0.031641
# 4  0.127522  0.062206

# %%
cross_validation(winesl2,12)
# Out:
# Accuracy: 99.07749077490774 %
# [[131   4]
#  [  1 406]]
#               precision    recall  f1-score   support
#
#     red wine       0.99      0.97      0.98       135
#   white wine       0.99      1.00      0.99       407
#
#    micro avg       0.99      0.99      0.99       542
#    macro avg       0.99      0.98      0.99       542
# weighted avg       0.99      0.99      0.99       542
#
# Accuracy: 98.70848708487084 %
# [[134   4]
#  [  3 401]]
#               precision    recall  f1-score   support
#
#     red wine       0.98      0.97      0.97       138
#   white wine       0.99      0.99      0.99       404
#
#    micro avg       0.99      0.99      0.99       542
#    macro avg       0.98      0.98      0.98       542
# weighted avg       0.99      0.99      0.99       542
#
# Accuracy: 98.70848708487084 %
# [[119   3]
#  [  4 416]]
#               precision    recall  f1-score   support
#
#     red wine       0.97      0.98      0.97       122
#   white wine       0.99      0.99      0.99       420
#
#    micro avg       0.99      0.99      0.99       542
#    macro avg       0.98      0.98      0.98       542
# weighted avg       0.99      0.99      0.99       542
#
# Accuracy: 98.70848708487084 %
# [[148   4]
#  [  3 387]]
#               precision    recall  f1-score   support
#
#     red wine       0.98      0.97      0.98       152
#   white wine       0.99      0.99      0.99       390
#
#    micro avg       0.99      0.99      0.99       542
#    macro avg       0.98      0.98      0.98       542
# weighted avg       0.99      0.99      0.99       542
#
# Accuracy: 97.23247232472325 %
# [[131   9]
#  [  6 396]]
#               precision    recall  f1-score   support
#
#     red wine       0.96      0.94      0.95       140
#   white wine       0.98      0.99      0.98       402
#
#    micro avg       0.97      0.97      0.97       542
#    macro avg       0.97      0.96      0.96       542
# weighted avg       0.97      0.97      0.97       542
#
# Accuracy: 97.22735674676525 %
# [[119   8]
#  [  7 407]]
#               precision    recall  f1-score   support
#
#     red wine       0.94      0.94      0.94       127
#   white wine       0.98      0.98      0.98       414
#
#    micro avg       0.97      0.97      0.97       541
#    macro avg       0.96      0.96      0.96       541
# weighted avg       0.97      0.97      0.97       541
#
# Accuracy: 97.96672828096118 %
# [[133   3]
#  [  8 397]]
#               precision    recall  f1-score   support
#
#     red wine       0.94      0.98      0.96       136
#   white wine       0.99      0.98      0.99       405
#
#    micro avg       0.98      0.98      0.98       541
#    macro avg       0.97      0.98      0.97       541
# weighted avg       0.98      0.98      0.98       541
#
# Accuracy: 97.41219963031423 %
# [[123   3]
#  [ 11 404]]
#               precision    recall  f1-score   support
#
#     red wine       0.92      0.98      0.95       126
#   white wine       0.99      0.97      0.98       415
#
#    micro avg       0.97      0.97      0.97       541
#    macro avg       0.96      0.97      0.96       541
# weighted avg       0.98      0.97      0.97       541
#
# Accuracy: 97.41219963031423 %
# [[130   5]
#  [  9 397]]
#               precision    recall  f1-score   support
#
#     red wine       0.94      0.96      0.95       135
#   white wine       0.99      0.98      0.98       406
#
#    micro avg       0.97      0.97      0.97       541
#    macro avg       0.96      0.97      0.97       541
# weighted avg       0.97      0.97      0.97       541
#
# Accuracy: 98.70609981515712 %
# [[123   5]
#  [  2 411]]
#               precision    recall  f1-score   support
#
#     red wine       0.98      0.96      0.97       128
#   white wine       0.99      1.00      0.99       413
#
#    micro avg       0.99      0.99      0.99       541
#    macro avg       0.99      0.98      0.98       541
# weighted avg       0.99      0.99      0.99       541
#
# Accuracy: 98.15157116451016 %
# [[119   5]
#  [  5 412]]
#               precision    recall  f1-score   support
#
#     red wine       0.96      0.96      0.96       124
#   white wine       0.99      0.99      0.99       417
#
#    micro avg       0.98      0.98      0.98       541
#    macro avg       0.97      0.97      0.97       541
# weighted avg       0.98      0.98      0.98       541
#
# Accuracy: 98.70609981515712 %
# [[134   2]
#  [  5 400]]
#               precision    recall  f1-score   support
#
#     red wine       0.96      0.99      0.97       136
#   white wine       1.00      0.99      0.99       405
#
#    micro avg       0.99      0.99      0.99       541
#    macro avg       0.98      0.99      0.98       541
# weighted avg       0.99      0.99      0.99       541

# %% [markdown]
# <h3>Pela norma max</h3>

# %%
normalizer = Normalizer(norm='max')
winesmax = X.copy()
winesmax.iloc[0:,0:12] = normalizer.transform(X)
winesmax.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0       0.044048          0.000952     0.001786        0.081548   0.000333
# 1       0.057522          0.003186     0.002743        0.119912   0.000469
# 2       0.193023          0.007209     0.009070        0.055814   0.001814
# 3       0.052941          0.005131     0.003399        0.013072   0.000797
# 4       0.072222          0.002667     0.004222        0.011111   0.000300
#
#    free sulfur dioxide  total sulfur dioxide   density        pH  sulphates  \
# 0             0.196429                   1.0  0.005942  0.017262   0.002619
# 1             0.176991                   1.0  0.008809  0.028319   0.004956
# 2             0.395349                   1.0  0.023127  0.076977   0.017907
# 3             0.241830                   1.0  0.006516  0.020980   0.004510
# 4             0.344444                   1.0  0.010992  0.036000   0.004000
#
#     alcohol   quality
# 0  0.051786  0.041667
# 1  0.097345  0.053097
# 2  0.290698  0.162791
# 3  0.060784  0.032680
# 4  0.136667  0.066667

# %%
cross_validation(winesmax,12)
# Out:
# Accuracy: 98.8929889298893 %
# [[131   4]
#  [  2 405]]
#               precision    recall  f1-score   support
#
#     red wine       0.98      0.97      0.98       135
#   white wine       0.99      1.00      0.99       407
#
#    micro avg       0.99      0.99      0.99       542
#    macro avg       0.99      0.98      0.99       542
# weighted avg       0.99      0.99      0.99       542
#
# Accuracy: 98.70848708487084 %
# [[135   3]
#  [  4 400]]
#               precision    recall  f1-score   support
#
#     red wine       0.97      0.98      0.97       138
#   white wine       0.99      0.99      0.99       404
#
#    micro avg       0.99      0.99      0.99       542
#    macro avg       0.98      0.98      0.98       542
# weighted avg       0.99      0.99      0.99       542
#
# Accuracy: 98.70848708487084 %
# [[119   3]
#  [  4 416]]
#               precision    recall  f1-score   support
#
#     red wine       0.97      0.98      0.97       122
#   white wine       0.99      0.99      0.99       420
#
#    micro avg       0.99      0.99      0.99       542
#    macro avg       0.98      0.98      0.98       542
# weighted avg       0.99      0.99      0.99       542
#
# Accuracy: 98.33948339483395 %
# [[148   4]
#  [  5 385]]
#               precision    recall  f1-score   support
#
#     red wine       0.97      0.97      0.97       152
#   white wine       0.99      0.99      0.99       390
#
#    micro avg       0.98      0.98      0.98       542
#    macro avg       0.98      0.98      0.98       542
# weighted avg       0.98      0.98      0.98       542
#
# Accuracy: 98.33948339483395 %
# [[133   7]
#  [  2 400]]
#               precision    recall  f1-score   support
#
#     red wine       0.99      0.95      0.97       140
#   white wine       0.98      1.00      0.99       402
#
#    micro avg       0.98      0.98      0.98       542
#    macro avg       0.98      0.97      0.98       542
# weighted avg       0.98      0.98      0.98       542
#
# Accuracy: 97.59704251386322 %
# [[121   6]
#  [  7 407]]
#               precision    recall  f1-score   support
#
#     red wine       0.95      0.95      0.95       127
#   white wine       0.99      0.98      0.98       414
#
#    micro avg       0.98      0.98      0.98       541
#    macro avg       0.97      0.97      0.97       541
# weighted avg       0.98      0.98      0.98       541
#
# Accuracy: 98.52125693160814 %
# [[132   4]
#  [  4 401]]
#               precision    recall  f1-score   support
#
#     red wine       0.97      0.97      0.97       136
#   white wine       0.99      0.99      0.99       405
#
#    micro avg       0.99      0.99      0.99       541
#    macro avg       0.98      0.98      0.98       541
# weighted avg       0.99      0.99      0.99       541
#
# Accuracy: 98.52125693160814 %
# [[124   2]
#  [  6 409]]
#               precision    recall  f1-score   support
#
#     red wine       0.95      0.98      0.97       126
#   white wine       1.00      0.99      0.99       415
#
#    micro avg       0.99      0.99      0.99       541
#    macro avg       0.97      0.98      0.98       541
# weighted avg       0.99      0.99      0.99       541
#
# Accuracy: 98.33641404805915 %
# [[130   5]
#  [  4 402]]
#               precision    recall  f1-score   support
#
#     red wine       0.97      0.96      0.97       135
#   white wine       0.99      0.99      0.99       406
#
#    micro avg       0.98      0.98      0.98       541
#    macro avg       0.98      0.98      0.98       541
# weighted avg       0.98      0.98      0.98       541
#
# Accuracy: 98.70609981515712 %
# [[122   6]
#  [  1 412]]
#               precision    recall  f1-score   support
#
#     red wine       0.99      0.95      0.97       128
#   white wine       0.99      1.00      0.99       413
#
#    micro avg       0.99      0.99      0.99       541
#    macro avg       0.99      0.98      0.98       541
# weighted avg       0.99      0.99      0.99       541
#
# Accuracy: 98.70609981515712 %
# [[123   1]
#  [  6 411]]
#               precision    recall  f1-score   support
#
#     red wine       0.95      0.99      0.97       124
#   white wine       1.00      0.99      0.99       417
#
#    micro avg       0.99      0.99      0.99       541
#    macro avg       0.98      0.99      0.98       541
# weighted avg       0.99      0.99      0.99       541
#
# Accuracy: 98.70609981515712 %
# [[134   2]
#  [  5 400]]
#               precision    recall  f1-score   support
#
#     red wine       0.96      0.99      0.97       136
#   white wine       1.00      0.99      0.99       405
#
#    micro avg       0.99      0.99      0.99       541
#    macro avg       0.98      0.99      0.98       541
# weighted avg       0.99      0.99      0.99       541

# %% [markdown]
# <h3>Por MinMaxScaler</h3>

# %%
scaller = MinMaxScaler(feature_range=(0, 12))
winesminmax = X.copy()
winesminmax.iloc[0:,0:12] = scaller.fit_transform(X)
winesminmax.head()
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/preprocessing/data.py:323: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by MinMaxScaler.
#   return self.partial_fit(X, y)
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0       3.570248              0.64     2.168675        2.411043   0.936877
# 1       2.677686              2.24     2.240964        2.383436   0.877076
# 2       4.462810              1.84     2.819277        0.331288   1.375415
# 3       4.264463              5.64     3.759036        0.257669   2.252492
# 4       2.677686              1.28     2.746988        0.073620   0.358804
#
#    free sulfur dioxide  total sulfur dioxide   density        pH  sulphates  \
# 0             1.333333              4.479263  2.577212  1.674419   1.483146
# 1             0.791667              2.958525  1.927126  4.465116   2.292135
# 2             0.666667              1.023041  1.695778  5.488372   3.707865
# 3             1.500000              4.064516  2.264893  4.558140   3.168539
# 4             1.250000              2.322581  0.497397  4.837209   0.943820
#
#     alcohol  quality
# 0  1.217391      8.0
# 1  5.217391      6.0
# 2  7.826087      8.0
# 3  2.260870      4.0
# 4  7.478261      6.0

# %%
cross_validation(winesminmax,12)
# Out:
# Accuracy: 98.8929889298893 %
# [[132   3]
#  [  3 404]]
#               precision    recall  f1-score   support
#
#     red wine       0.98      0.98      0.98       135
#   white wine       0.99      0.99      0.99       407
#
#    micro avg       0.99      0.99      0.99       542
#    macro avg       0.99      0.99      0.99       542
# weighted avg       0.99      0.99      0.99       542
#
# Accuracy: 98.8929889298893 %
# [[134   4]
#  [  2 402]]
#               precision    recall  f1-score   support
#
#     red wine       0.99      0.97      0.98       138
#   white wine       0.99      1.00      0.99       404
#
#    micro avg       0.99      0.99      0.99       542
#    macro avg       0.99      0.98      0.99       542
# weighted avg       0.99      0.99      0.99       542
#
# Accuracy: 99.07749077490774 %
# [[120   2]
#  [  3 417]]
#               precision    recall  f1-score   support
#
#     red wine       0.98      0.98      0.98       122
#   white wine       1.00      0.99      0.99       420
#
#    micro avg       0.99      0.99      0.99       542
#    macro avg       0.99      0.99      0.99       542
# weighted avg       0.99      0.99      0.99       542
#
# Accuracy: 98.70848708487084 %
# [[147   5]
#  [  2 388]]
#               precision    recall  f1-score   support
#
#     red wine       0.99      0.97      0.98       152
#   white wine       0.99      0.99      0.99       390
#
#    micro avg       0.99      0.99      0.99       542
#    macro avg       0.99      0.98      0.98       542
# weighted avg       0.99      0.99      0.99       542
#
# Accuracy: 99.2619926199262 %
# [[137   3]
#  [  1 401]]
#               precision    recall  f1-score   support
#
#     red wine       0.99      0.98      0.99       140
#   white wine       0.99      1.00      1.00       402
#
#    micro avg       0.99      0.99      0.99       542
#    macro avg       0.99      0.99      0.99       542
# weighted avg       0.99      0.99      0.99       542
#
# Accuracy: 97.96672828096118 %
# [[122   5]
#  [  6 408]]
#               precision    recall  f1-score   support
#
#     red wine       0.95      0.96      0.96       127
#   white wine       0.99      0.99      0.99       414
#
#    micro avg       0.98      0.98      0.98       541
#    macro avg       0.97      0.97      0.97       541
# weighted avg       0.98      0.98      0.98       541
#
# Accuracy: 98.70609981515712 %
# [[133   3]
#  [  4 401]]
#               precision    recall  f1-score   support
#
#     red wine       0.97      0.98      0.97       136
#   white wine       0.99      0.99      0.99       405
#
#    micro avg       0.99      0.99      0.99       541
#    macro avg       0.98      0.98      0.98       541
# weighted avg       0.99      0.99      0.99       541
#
# Accuracy: 97.59704251386322 %
# [[120   6]
#  [  7 408]]
#               precision    recall  f1-score   support
#
#     red wine       0.94      0.95      0.95       126
#   white wine       0.99      0.98      0.98       415
#
#    micro avg       0.98      0.98      0.98       541
#    macro avg       0.97      0.97      0.97       541
# weighted avg       0.98      0.98      0.98       541
#
# Accuracy: 98.15157116451016 %
# [[130   5]
#  [  5 401]]
#               precision    recall  f1-score   support
#
#     red wine       0.96      0.96      0.96       135
#   white wine       0.99      0.99      0.99       406
#
#    micro avg       0.98      0.98      0.98       541
#    macro avg       0.98      0.98      0.98       541
# weighted avg       0.98      0.98      0.98       541
#
# Accuracy: 99.44547134935306 %
# [[126   2]
#  [  1 412]]
#               precision    recall  f1-score   support
#
#     red wine       0.99      0.98      0.99       128
#   white wine       1.00      1.00      1.00       413
#
#    micro avg       0.99      0.99      0.99       541
#    macro avg       0.99      0.99      0.99       541
# weighted avg       0.99      0.99      0.99       541
#
# Accuracy: 98.33641404805915 %
# [[120   4]
#  [  5 412]]
#               precision    recall  f1-score   support
#
#     red wine       0.96      0.97      0.96       124
#   white wine       0.99      0.99      0.99       417
#
#    micro avg       0.98      0.98      0.98       541
#    macro avg       0.98      0.98      0.98       541
# weighted avg       0.98      0.98      0.98       541
#
# Accuracy: 98.52125693160814 %
# [[131   5]
#  [  3 402]]
#               precision    recall  f1-score   support
#
#     red wine       0.98      0.96      0.97       136
#   white wine       0.99      0.99      0.99       405
#
#    micro avg       0.99      0.99      0.99       541
#    macro avg       0.98      0.98      0.98       541
# weighted avg       0.99      0.99      0.99       541

# %%
# Create scaler
scaler = preprocessing.StandardScaler()

# Transform the feature
standardized = scaler.fit_transform(X)

# Show feature
winesS = X.copy()
winesS.iloc[0:,0:12] = standardized
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/preprocessing/data.py:625: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# /usr/local/lib/python3.6/dist-packages/sklearn/base.py:462: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, **fit_params).transform(X)

# %%
cross_validation(winesS)
# Out:
# Accuracy: 98.76923076923076 %
# [[156   4]
#  [  4 486]]
#               precision    recall  f1-score   support
#
#     red wine       0.97      0.97      0.97       160
#   white wine       0.99      0.99      0.99       490
#
#    micro avg       0.99      0.99      0.99       650
#    macro avg       0.98      0.98      0.98       650
# weighted avg       0.99      0.99      0.99       650
#
# Accuracy: 98.92307692307692 %
# [[151   3]
#  [  4 492]]
#               precision    recall  f1-score   support
#
#     red wine       0.97      0.98      0.98       154
#   white wine       0.99      0.99      0.99       496
#
#    micro avg       0.99      0.99      0.99       650
#    macro avg       0.98      0.99      0.99       650
# weighted avg       0.99      0.99      0.99       650
#
# Accuracy: 98.76923076923076 %
# [[164   5]
#  [  3 478]]
#               precision    recall  f1-score   support
#
#     red wine       0.98      0.97      0.98       169
#   white wine       0.99      0.99      0.99       481
#
#    micro avg       0.99      0.99      0.99       650
#    macro avg       0.99      0.98      0.98       650
# weighted avg       0.99      0.99      0.99       650
#
# Accuracy: 99.23076923076923 %
# [[171   3]
#  [  2 474]]
#               precision    recall  f1-score   support
#
#     red wine       0.99      0.98      0.99       174
#   white wine       0.99      1.00      0.99       476
#
#    micro avg       0.99      0.99      0.99       650
#    macro avg       0.99      0.99      0.99       650
# weighted avg       0.99      0.99      0.99       650
#
# Accuracy: 98.15384615384616 %
# [[149   8]
#  [  4 489]]
#               precision    recall  f1-score   support
#
#     red wine       0.97      0.95      0.96       157
#   white wine       0.98      0.99      0.99       493
#
#    micro avg       0.98      0.98      0.98       650
#    macro avg       0.98      0.97      0.97       650
# weighted avg       0.98      0.98      0.98       650
#
# Accuracy: 98.61538461538461 %
# [[153   4]
#  [  5 488]]
#               precision    recall  f1-score   support
#
#     red wine       0.97      0.97      0.97       157
#   white wine       0.99      0.99      0.99       493
#
#    micro avg       0.99      0.99      0.99       650
#    macro avg       0.98      0.98      0.98       650
# weighted avg       0.99      0.99      0.99       650
#
# Accuracy: 98.3076923076923 %
# [[154   5]
#  [  6 485]]
#               precision    recall  f1-score   support
#
#     red wine       0.96      0.97      0.97       159
#   white wine       0.99      0.99      0.99       491
#
#    micro avg       0.98      0.98      0.98       650
#    macro avg       0.98      0.98      0.98       650
# weighted avg       0.98      0.98      0.98       650
#
# Accuracy: 99.69183359013869 %
# [[163   0]
#  [  2 484]]
#               precision    recall  f1-score   support
#
#     red wine       0.99      1.00      0.99       163
#   white wine       1.00      1.00      1.00       486
#
#    micro avg       1.00      1.00      1.00       649
#    macro avg       0.99      1.00      1.00       649
# weighted avg       1.00      1.00      1.00       649
#
# Accuracy: 98.92141756548536 %
# [[146   3]
#  [  4 496]]
#               precision    recall  f1-score   support
#
#     red wine       0.97      0.98      0.98       149
#   white wine       0.99      0.99      0.99       500
#
#    micro avg       0.99      0.99      0.99       649
#    macro avg       0.98      0.99      0.98       649
# weighted avg       0.99      0.99      0.99       649
#
# Accuracy: 99.53775038520801 %
# [[157   0]
#  [  3 489]]
#               precision    recall  f1-score   support
#
#     red wine       0.98      1.00      0.99       157
#   white wine       1.00      0.99      1.00       492
#
#    micro avg       1.00      1.00      1.00       649
#    macro avg       0.99      1.00      0.99       649
# weighted avg       1.00      1.00      1.00       649
